# %% [markdown]
# <h1><center>DUELING DOUBLE DEEP Q-LEARNING</center></h1>

# %% [markdown]
# ![cartPole.png](attachment:cartPole.png)

# %%
import numpy as np
import random
import gym
from collections import deque
from keras.models import Sequential, Model, load_model
from keras.layers import Input, Dense, Activation, Add, Lambda
from keras.optimizers import Adam 
from keras import backend as K

EVIRONMENT_NAME = "CartPole-v1"

# %%
class Memory:
  def __init__(self, capacity = 2000):
       self.buffer = deque(maxlen = capacity)
       self.capacity = capacity 

  def append(self, experience):
      self.buffer.append(experience)     

  def sample(self, batch_size):
      return random.sample(self.buffer, batch_size)

# %%
class DDDQN_Agent:
    def __init__(self, env, discount_rate = 0.99, 
                 lr = 0.001, batch_size = 64, 
                 epsilon_decay = 0.999, epsilon_min = 0.01):
        self.env = env
        self.state_size = env.observation_space.shape[0]
        self.discount_rate = discount_rate
  
        self.epsilon = 1.
        self.epsilon_decay = epsilon_decay
        self.epsilon_min = epsilon_min
        self.batch_size = batch_size

        self.memory = Memory()

        self.dqn_model = self.create_model(lr, "DDQN")
        self.target_dqn_model = self.create_model(lr, "DDQN_TARGET")
        self.hard_update_target_network()

    def load_model(self):
        self.dqn_model = load_model('cartPole-v1-DDDQN-1.h5')
        
    def create_model(self, lr, name):
        inputs = Input(shape=(self.state_size,))
        
        #Advantage stream
        advantage_fc1 = Dense(16, activation= 'relu', kernel_initializer= 'he_uniform')(inputs)
        advantage_fc2 = Dense(32, activation= 'relu', kernel_initializer= 'he_uniform')(advantage_fc1)
        advantage = Dense(self.env.action_space.n, activation= 'linear', kernel_initializer= 'he_uniform')(advantage_fc2)
        
        #Value Stream
        value_fc1 = Dense(16, activation= 'relu', kernel_initializer= 'he_uniform')(inputs)
        value_fc2 = Dense(32, activation= 'relu', kernel_initializer= 'he_uniform')(value_fc1)
        value = Dense(1, activation= 'linear', kernel_initializer= 'he_uniform')(advantage_fc2)       
        
        #Merge layer
        outputs =  Lambda(lambda a: a[0] + a[1] - K.mean(a[1], axis=1, keepdims=True))([value, advantage])
        
        model = Model(inputs= inputs, outputs= outputs, name= name)
        model.compile(loss= 'mse', optimizer= Adam(lr = lr))        
        return model
    
    #Update target DAN with weights from current DQN
    def hard_update_target_network(self):
        self.target_dqn_model.set_weights(self.dqn_model.get_weights())  

    #Epsilon greedy policy (behaviour policy)
    def epsilon_greedy_action(self, state):
        if np.random.rand() <= self.epsilon:
            action = np.random.choice(self.env.action_space.n)
        else:
            q = self.dqn_model.predict(state)
            action = np.argmax(q[0])
        return action
    
    
    #Deterministic greedy policy
    def act(self, state):
        q = self.dqn_model.predict(np.reshape(state,[1, self.state_size]))
        action = np.argmax(q[0])
        return action        
        

    #Learn from a mini-batch of experiences
    def learn(self):
        #sample memory for replay
        batch = self.memory.sample(self.batch_size)

        states = [experience[0] for experience in batch]
        actions = [experience[1] for experience in batch]        
        rewards = [experience[2] for experience in batch]
        next_states = [experience[3] for experience in batch]
        dones = [experience[4] for experience in batch]

        states = np.reshape(states, [self.batch_size, self.state_size])
        next_states = np.reshape(next_states, [self.batch_size, self.state_size])
       
        #Use dqn model to predict Q-value of current states in mini-batch
        q_states = self.dqn_model.predict(states)

        #Use dqn model to predict Q-value of next states in mini-batch
        q_next_states = self.dqn_model.predict(next_states)
        
        #Use target dqn model to predict target Q-value of next states in mini-batch
        q_target_next_states = self.target_dqn_model.predict(next_states)

        q_optimal = q_states
        
        for i in range(self.batch_size):
            if dones[i]:
                #for terminal states target is immediate reward 
                #in current time step                  
                q_optimal[i][actions[i]] = rewards[i]
            else:
                #current dqn model determines greedy action 
                max_next_action = np.argmax(q_next_states[i])
                
                #Use Q-Value of maximal action obtained from target dqn as 
                #Q-Value target estimate
                #update rule: 𝑞(𝑠, 𝑎) += 𝛼(𝑅+ 𝑚𝑎𝑥𝑎′ 𝑞(𝑠′, 𝑎′)− 𝑞(𝑠, 𝑎))                
                q_optimal[i][actions[i]] = rewards[i] + \
                   self.discount_rate * (q_target_next_states[i][max_next_action])

        self.dqn_model.fit(states, q_optimal, batch_size = self.batch_size,
                       epochs=1, verbose=0)            

    def train(self, max_episodes):
        rewards = []

        for e in range(max_episodes):
            done = False
            episode_total = 0
            
            #start a new episode
            state = env.reset()

            while not done:
                 #get next action following behaviour policy 
                 action = self.epsilon_greedy_action(np.reshape(state, [1, self.state_size]))
                
                 #interact with environment   
                 next_state, reward, done, info = env.step(action)
                 reward = reward if not done or episode_total == 499 else -100

                 #append experience to replay memory
                 self.memory.append((state, action, reward, next_state, done))
                    
                 #exploration deacy 
                 if self.epsilon > self.epsilon_min:
                    self.epsilon = max(self.epsilon_min, self.epsilon * self.epsilon_decay)
                                       
                 if len(self.memory.buffer) >= 1000:
                    self.learn()
                    
                 episode_total += reward
                 state = next_state

            self.hard_update_target_network()
            episode_total = episode_total if episode_total == 500 else episode_total + 100
            rewards.append(episode_total)
            print("episode:", e, "  episode_total:", episode_total, "  epsilon:", self.epsilon)
            
        self.dqn_model.save('cartPole-v1-DDDQN-1.h5')

# %%
env = gym.make(EVIRONMENT_NAME)
agent = DDDQN_Agent(env)
agent.train(200)
# Out:
# episode: 0   episode_total: 11.0   epsilon: 0.988065780494209
# episode: 1   episode_total: 17.0   epsilon: 0.9704309672630859
# episode: 2   episode_total: 34.0   epsilon: 0.9370369888620198
# episode: 3   episode_total: 26.0   epsilon: 0.9120631656822724
# episode: 4   episode_total: 16.0   epsilon: 0.8966815144183318
# episode: 5   episode_total: 16.0   epsilon: 0.8815592697443159
# episode: 6   episode_total: 10.0   epsilon: 0.8719104583701925
# episode: 7   episode_total: 34.0   epsilon: 0.8419067177676068
# episode: 8   episode_total: 23.0   epsilon: 0.8219316276865206
# episode: 9   episode_total: 35.0   epsilon: 0.7928540855310416
# episode: 10   episode_total: 12.0   epsilon: 0.7826085988474126
# episode: 11   episode_total: 18.0   epsilon: 0.7678721062162944
# episode: 12   episode_total: 13.0   epsilon: 0.7571914943525904
# episode: 13   episode_total: 8.0   epsilon: 0.750403966288439
# episode: 14   episode_total: 8.0   epsilon: 0.7436772821951526
# episode: 15   episode_total: 14.0   epsilon: 0.7325998717165821
# episode: 16   episode_total: 25.0   epsilon: 0.7137884761549381
# episode: 17   episode_total: 10.0   epsilon: 0.7059759437435444
# episode: 18   episode_total: 12.0   epsilon: 0.6968531211932361
# episode: 19   episode_total: 12.0   epsilon: 0.6878481863585387
# episode: 20   episode_total: 8.0   epsilon: 0.6816822575233553
# episode: 21   episode_total: 23.0   epsilon: 0.6655086551356549
# episode: 22   episode_total: 19.0   epsilon: 0.6523241732116479
# episode: 23   episode_total: 17.0   epsilon: 0.640681613386349
# episode: 24   episode_total: 15.0   epsilon: 0.6305072317473174
# episode: 25   episode_total: 9.0   epsilon: 0.6242304567266527
# episode: 26   episode_total: 20.0   epsilon: 0.6112518790281489
# episode: 27   episode_total: 13.0   epsilon: 0.6027497547577038
# episode: 28   episode_total: 16.0   epsilon: 0.5925845744544587
# episode: 29   episode_total: 12.0   epsilon: 0.5849270275271061
# episode: 30   episode_total: 17.0   epsilon: 0.5744873593512512
# episode: 31   episode_total: 11.0   epsilon: 0.5676313011014509
# episode: 32   episode_total: 9.0   epsilon: 0.5619804635022894
# episode: 33   episode_total: 8.0   epsilon: 0.5569428234918348
# episode: 34   episode_total: 19.0   epsilon: 0.5459091539334175
# episode: 35   episode_total: 16.0   epsilon: 0.5367025720391522
# episode: 36   episode_total: 11.0   epsilon: 0.5302974457351142
# episode: 37   episode_total: 8.0   epsilon: 0.5255438149533099
# episode: 38   episode_total: 9.0   epsilon: 0.5203119633204238
# episode: 39   episode_total: 10.0   epsilon: 0.5146170632018707
# episode: 40   episode_total: 32.0   epsilon: 0.4979036311114436
# episode: 41   episode_total: 11.0   epsilon: 0.4919615398850291
# episode: 42   episode_total: 8.0   epsilon: 0.4875515553786555
# episode: 43   episode_total: 11.0   epsilon: 0.48173300809637676
# episode: 44   episode_total: 12.0   epsilon: 0.4755079167339349
# episode: 45   episode_total: 10.0   epsilon: 0.4703034042831738
# episode: 46   episode_total: 14.0   epsilon: 0.46329802172888124
# episode: 47   episode_total: 10.0   epsilon: 0.45822714858955943
# episode: 48   episode_total: 11.0   epsilon: 0.452758565214779
# episode: 49   episode_total: 9.0   epsilon: 0.4482512994620033
# episode: 50   episode_total: 8.0   epsilon: 0.44423313721693997
# episode: 51   episode_total: 9.0   epsilon: 0.43981074312114604
# episode: 52   episode_total: 12.0   epsilon: 0.43412738322656147
# episode: 53   episode_total: 12.0   epsilon: 0.42851746532991924
# episode: 54   episode_total: 11.0   epsilon: 0.4234034438366067
# episode: 55   episode_total: 12.0   epsilon: 0.4179321037441544
# episode: 56   episode_total: 10.0   epsilon: 0.4133577680476022
# episode: 57   episode_total: 10.0   epsilon: 0.40883349920850676
# episode: 58   episode_total: 12.0   epsilon: 0.4035504360971442
# episode: 59   episode_total: 20.0   epsilon: 0.39516008821566384
# episode: 60   episode_total: 12.0   epsilon: 0.3900537168219873
# episode: 61   episode_total: 13.0   epsilon: 0.3846283180848215
# episode: 62   episode_total: 12.0   epsilon: 0.3796580412293454
# episode: 63   episode_total: 10.0   epsilon: 0.3755026214496253
# episode: 64   episode_total: 11.0   epsilon: 0.37102129074024554
# episode: 65   episode_total: 13.0   epsilon: 0.36586062092624033
# episode: 66   episode_total: 12.0   epsilon: 0.361132865607614
# episode: 67   episode_total: 10.0   epsilon: 0.3571802069256231
# episode: 68   episode_total: 11.0   epsilon: 0.352917539933049
# episode: 69   episode_total: 51.0   epsilon: 0.3350260916703695
# episode: 70   episode_total: 11.0   epsilon: 0.3310278167522081
# episode: 71   episode_total: 10.0   epsilon: 0.3274046627873518
# episode: 72   episode_total: 8.0   epsilon: 0.324469779929346
# episode: 73   episode_total: 7.0   epsilon: 0.32188308869613635
# episode: 74   episode_total: 10.0   epsilon: 0.31836002528572027
# episode: 75   episode_total: 17.0   epsilon: 0.3126779951041253
# episode: 76   episode_total: 9.0   epsilon: 0.3095652482070879
# episode: 77   episode_total: 9.0   epsilon: 0.3064834890782873
# episode: 78   episode_total: 9.0   epsilon: 0.3034324092307786
# episode: 79   episode_total: 8.0   epsilon: 0.3007124156643058
# episode: 80   episode_total: 12.0   epsilon: 0.2968265240399636
# episode: 81   episode_total: 15.0   epsilon: 0.29211275315428575
# episode: 82   episode_total: 9.0   epsilon: 0.2892047357043746
# episode: 83   episode_total: 7.0   epsilon: 0.28689917937610226
# episode: 84   episode_total: 13.0   epsilon: 0.28290859454547135
# episode: 85   episode_total: 8.0   epsilon: 0.2803725781752547
# episode: 86   episode_total: 11.0   epsilon: 0.2770265502839066
# episode: 87   episode_total: 11.0   epsilon: 0.27372045462388644
# episode: 88   episode_total: 9.0   epsilon: 0.27099553470906346
# episode: 89   episode_total: 10.0   epsilon: 0.268029443956713
# episode: 90   episode_total: 13.0   epsilon: 0.2643013251257632
# episode: 91   episode_total: 37.0   epsilon: 0.2544414683340336
# episode: 92   episode_total: 102.0   epsilon: 0.2295266829410795
# episode: 93   episode_total: 50.0   epsilon: 0.21810874556231533
# episode: 94   episode_total: 33.0   epsilon: 0.21081411211133688
# episode: 95   episode_total: 45.0   epsilon: 0.20133168951671884
# episode: 96   episode_total: 30.0   epsilon: 0.19518312769222232
# episode: 97   episode_total: 48.0   epsilon: 0.18584513472466632
# episode: 98   episode_total: 55.0   epsilon: 0.17571892461558297
# episode: 99   episode_total: 40.0   epsilon: 0.16865668272495074
# episode: 100   episode_total: 42.0   epsilon: 0.1615546816127524
# episode: 101   episode_total: 56.0   epsilon: 0.15259924208778378
# episode: 102   episode_total: 42.0   epsilon: 0.1461734072526738
# episode: 103   episode_total: 30.0   epsilon: 0.1417093497873648
# episode: 104   episode_total: 82.0   epsilon: 0.13041694662196698
# episode: 105   episode_total: 77.0   epsilon: 0.12062632858643366
# episode: 106   episode_total: 93.0   epsilon: 0.10979890347177342
# episode: 107   episode_total: 65.0   epsilon: 0.10278274825565252
# episode: 108   episode_total: 48.0   epsilon: 0.09786539401635165
# episode: 109   episode_total: 67.0   epsilon: 0.09142865865928752
# episode: 110   episode_total: 47.0   epsilon: 0.08714165085527924
# episode: 111   episode_total: 94.0   epsilon: 0.0792404922286108
# episode: 112   episode_total: 312.0   epsilon: 0.057935529344130744
# episode: 113   episode_total: 114.0   epsilon: 0.051638798089334734
# episode: 114   episode_total: 114.0   epsilon: 0.04602642796740446
# episode: 115   episode_total: 280.0   epsilon: 0.03474637183064226
# episode: 116   episode_total: 329.0   epsilon: 0.024975867251738625
# episode: 117   episode_total: 307.0   epsilon: 0.018352319063218867
# episode: 118   episode_total: 500.0   epsilon: 0.01112845986931047
# episode: 119   episode_total: 332.0   epsilon: 0.01
# episode: 120   episode_total: 494.0   epsilon: 0.01
# episode: 121   episode_total: 318.0   epsilon: 0.01
# episode: 122   episode_total: 288.0   epsilon: 0.01
# episode: 123   episode_total: 306.0   epsilon: 0.01
# episode: 124   episode_total: 352.0   epsilon: 0.01
# episode: 125   episode_total: 365.0   epsilon: 0.01
# episode: 126   episode_total: 246.0   epsilon: 0.01
# episode: 127   episode_total: 218.0   epsilon: 0.01
# episode: 128   episode_total: 286.0   epsilon: 0.01
# episode: 129   episode_total: 282.0   epsilon: 0.01
# episode: 130   episode_total: 336.0   epsilon: 0.01
# episode: 131   episode_total: 310.0   epsilon: 0.01
# episode: 132   episode_total: 271.0   epsilon: 0.01
# episode: 133   episode_total: 264.0   epsilon: 0.01
# episode: 134   episode_total: 244.0   epsilon: 0.01
# episode: 135   episode_total: 241.0   epsilon: 0.01
# episode: 136   episode_total: 284.0   epsilon: 0.01
# episode: 137   episode_total: 265.0   epsilon: 0.01
# episode: 138   episode_total: 267.0   epsilon: 0.01
# episode: 139   episode_total: 304.0   epsilon: 0.01
# episode: 140   episode_total: 322.0   epsilon: 0.01
# episode: 141   episode_total: 482.0   epsilon: 0.01
# episode: 142   episode_total: 329.0   epsilon: 0.01
# episode: 143   episode_total: 351.0   epsilon: 0.01
# episode: 144   episode_total: 460.0   epsilon: 0.01
# episode: 145   episode_total: 500.0   epsilon: 0.01
# episode: 146   episode_total: 500.0   epsilon: 0.01
# episode: 147   episode_total: 500.0   epsilon: 0.01
# episode: 148   episode_total: 500.0   epsilon: 0.01
# episode: 149   episode_total: 500.0   epsilon: 0.01
# episode: 150   episode_total: 500.0   epsilon: 0.01
# episode: 151   episode_total: 500.0   epsilon: 0.01
# episode: 152   episode_total: 500.0   epsilon: 0.01
# episode: 153   episode_total: 500.0   epsilon: 0.01
# episode: 154   episode_total: 500.0   epsilon: 0.01
# episode: 155   episode_total: 500.0   epsilon: 0.01
# episode: 156   episode_total: 235.0   epsilon: 0.01
# episode: 157   episode_total: 500.0   epsilon: 0.01
# episode: 158   episode_total: 24.0   epsilon: 0.01
# episode: 159   episode_total: 53.0   epsilon: 0.01
# episode: 160   episode_total: 17.0   epsilon: 0.01
# episode: 161   episode_total: 26.0   epsilon: 0.01
# episode: 162   episode_total: 30.0   epsilon: 0.01
# episode: 163   episode_total: 49.0   epsilon: 0.01
# episode: 164   episode_total: 128.0   epsilon: 0.01
# episode: 165   episode_total: 294.0   epsilon: 0.01
# episode: 166   episode_total: 297.0   epsilon: 0.01
# episode: 167   episode_total: 500.0   epsilon: 0.01
# episode: 168   episode_total: 500.0   epsilon: 0.01
# episode: 169   episode_total: 500.0   epsilon: 0.01
# episode: 170   episode_total: 500.0   epsilon: 0.01
# episode: 171   episode_total: 500.0   epsilon: 0.01
# episode: 172   episode_total: 500.0   epsilon: 0.01
# episode: 173   episode_total: 500.0   epsilon: 0.01
# episode: 174   episode_total: 500.0   epsilon: 0.01
# episode: 175   episode_total: 500.0   epsilon: 0.01
# episode: 176   episode_total: 500.0   epsilon: 0.01
# episode: 177   episode_total: 500.0   epsilon: 0.01
# episode: 178   episode_total: 500.0   epsilon: 0.01
# episode: 179   episode_total: 500.0   epsilon: 0.01
# episode: 180   episode_total: 500.0   epsilon: 0.01
# episode: 181   episode_total: 500.0   epsilon: 0.01
# episode: 182   episode_total: 491.0   epsilon: 0.01
# episode: 183   episode_total: 500.0   epsilon: 0.01
# episode: 184   episode_total: 500.0   epsilon: 0.01
# episode: 185   episode_total: 500.0   epsilon: 0.01
# episode: 186   episode_total: 500.0   epsilon: 0.01
# episode: 187   episode_total: 500.0   epsilon: 0.01
# episode: 188   episode_total: 500.0   epsilon: 0.01
# episode: 189   episode_total: 500.0   epsilon: 0.01
# episode: 190   episode_total: 500.0   epsilon: 0.01
# episode: 191   episode_total: 500.0   epsilon: 0.01
# episode: 192   episode_total: 500.0   epsilon: 0.01
# episode: 193   episode_total: 500.0   epsilon: 0.01
# episode: 194   episode_total: 500.0   epsilon: 0.01
# episode: 195   episode_total: 500.0   epsilon: 0.01
# episode: 196   episode_total: 500.0   epsilon: 0.01
# episode: 197   episode_total: 500.0   epsilon: 0.01
# episode: 198   episode_total: 500.0   epsilon: 0.01
# episode: 199   episode_total: 500.0   epsilon: 0.01

# %%
import gym
from IPython import display
import matplotlib.pyplot as plt
import time

# %matplotlib inline

MAX_EPISODES = 10

env = gym.make(EVIRONMENT_NAME)
for episode in range(3):
    state = env.reset()
    done = False
    steps = 0
    rewards = 0
    while not done:
       plt.imshow(env.render(mode='rgb_array'))
       display.clear_output(wait=True)
       display.display(plt.gcf())
       _, reward, done, _ = env.step(env.action_space.sample())
       time.sleep(0.005)
       rewards+= reward 
    print('end of episode: %d score: %.2f'%(episode, rewards))
    time.sleep(3)
display.clear_output()

# %%
import gym
from IPython import display
import matplotlib.pyplot as plt
import time


# %matplotlib inline

env = gym.make(EVIRONMENT_NAME)
agent = DDDQN_Agent(env)
agent.load_model()

for episode in range(3):
    state = env.reset()
    done = False
    rewards = 0
    while not done and rewards < 500:
        plt.imshow(env.render(mode='rgb_array'))
        display.clear_output(wait=True)
        display.display(plt.gcf())
        action = agent.act(state)
        state, reward, done, _ = env.step(action)
        rewards+=1
        if rewards % 20 == 0:
           print('episode: %d score: %.2f'%(episode, rewards))
           time.sleep(1) 
    time.sleep(1)
display.clear_output()
# Out:
# episode: 0 score: 120.00
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-8fffb2847f7f> in <module>()
#      24         if rewards % 20 == 0:
#      25            print('episode: %d score: %.2f'%(episode, rewards))
# ---> 26            time.sleep(1)
#      27     time.sleep(1)
#      28 display.clear_output()
#
# KeyboardInterrupt:

# %%
'\[]P=-09
'
